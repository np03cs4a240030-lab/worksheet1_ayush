# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs4a240030-lab/worksheet1_ayush/blob/main/workshop5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
def cost_function(X, Y, W):
    m = len(Y)
    y_pred = np.dot(X, W)
    cost = (1 / (2 * m)) * np.sum((y_pred - Y) ** 2)
    return cost

# %%
# Test case
X_test = np.array([[1, 2], [3, 4], [5, 6]])
Y_test = np.array([3, 7, 11])
W_test = np.array([1, 1])
cost = cost_function(X_test, Y_test, W_test)
if cost == 0:
  print("Proceed Further")
else:
  print("something went wrong: Reimplement a cost function")
print("Cost function output:", cost_function(X_test, Y_test, W_test))
# Out:
# Proceed Further
# Cost function output: 0.0

# %%
def gradient_descent(X, Y, W, alpha, iterations):
    cost_history = []
    m = len(Y)

    for iteration in range(iterations):
        Y_pred = np.dot(X, W)
        loss = Y_pred - Y
        dw = (1 / m) * np.dot(X.T, loss)
        W = W - alpha * dw
        cost = cost_function(X, Y, W)
        cost_history.append(cost)

    return W, cost_history

# %%
# Generate random test data
np.random.seed(0) # For reproducibility
X = np.random.rand(100, 3) # 100 samples, 3 features
Y = np.random.rand(100)
W = np.random.rand(3) # Initial guess for parameters
# Set hyperparameters
alpha = 0.01
iterations = 1000
# Test the gradient_descent function
final_params, cost_history = gradient_descent(X, Y, W, alpha, iterations)
# Print the final parameters and cost history
print("Final Parameters:", final_params)
print("Cost History:", cost_history)
# Out:
# Final Parameters: [0.3996496  0.92745322 0.09826523]
# ...

# %%
def rmse(Y, Y_pred):
    return np.sqrt(np.mean((Y - Y_pred) ** 2))

# %%
def r2(Y, Y_pred):
    mean_y = np.mean(Y)
    ss_tot = np.sum((Y - mean_y) ** 2)
    ss_res = np.sum((Y - Y_pred) ** 2)
    return 1 - (ss_res / ss_tot)

# %%
def main():
    # Load data
    data = pd.read_csv("/content/drive/MyDrive/5CS037 - 2025 - Materials/Week - 5 - Drawing Lines Through Data - Linear Regression Demystified/Datasets/student.csv")

    # Features
    X = data[['Math', 'Reading']].values

    # ✅ Add bias column
    X = np.c_[np.ones(X.shape[0]), X]

    # Target
    Y = data['Writing'].values

    # Train-test split
    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.2, random_state=42
    )

    # Hyperparameters
    alpha = 0.00001
    iterations = 1000

    # ✅ Initialize weights correctly
    W = np.zeros(X_train.shape[1])

    # Train model
    W_optimal, cost_history = gradient_descent(
        X_train, Y_train, W, alpha, iterations
    )

    # Predictions
    Y_pred = np.dot(X_test, W_optimal)

    # Evaluation
    model_rmse = rmse(Y_test, Y_pred)
    model_r2 = r2(Y_test, Y_pred)

    print("Final Weights:", W_optimal)
    print("Cost History (first 10):", cost_history[:10])
    print("RMSE on Test Set:", model_rmse)
    print("R-Squared on Test Set:", model_r2)
if __name__ == "__main__":
    main()
# Out:
# Final Weights: [0.00683132 0.34807361 0.64609314]
# Cost History (first 10): [np.float64(2013.1230445288195), np.float64(1640.2176703623718), np.float64(1336.9776386789026), np.float64(1090.3880235909312), np.float64(889.8653565471526), np.float64(726.8033798134234), np.float64(594.2036625984557), np.float64(486.3752257270098), np.float64(398.6902826366499), np.float64(327.38561300819185)]
# RMSE on Test Set: 5.2797921597911115
# R-Squared on Test Set: 0.8886367884574308
